# %%
from __future__ import division
from IPython.display import clear_output
import numpy as np
import gym
import matplotlib.pyplot as plt
from IPython import display
import random

# how to render in Jupyter: 
# https://stackoverflow.com/questions/40195740/how-to-run-openai-gym-render-over-a-server
# https://www.youtube.com/watch?v=O84KgRt6AJI
def show_state(env, step=0, name='', info=''):
    plt.figure(3)
    plt.clf()
    plt.imshow(env.render())
    plt.title("%s | Step: %d %s" % (name, step, info))
    plt.axis('off')

    display.clear_output(wait=True)
    display.display(plt.gcf())
    
# To transform pixel matrix to a single vector.
def getState(inState):
    # each row is all 1 color
    rgbRows = np.reshape(inState,(len(inState[0])*len(inState), 3)).T

    # add each with appropriate shifting
    # get RRRRRRRR GGGGGGGG BBBBBBBB
    return np.add(np.left_shift(rgbRows[0], 16),
        np.add(np.left_shift(rgbRows[1], 8), rgbRows[2]))

# %%
# import to do training
from tpg.trainer import Trainer
# import to run an agent (always needed)
from tpg.agent import Agent

from tpg.configurations import DefaultConfiguration

# %%
env = gym.make('Assault-v0', render_mode='rgb_array') # make the environment

print(env.action_space) # learn size of action space
# Out:
# /home/bryce/anaconda3/envs/pytpg/lib/python3.11/site-packages/gym/envs/registration.py:555: UserWarning: WARN: The environment Assault-v0 is out of date. You should consider upgrading to version `v4`.
#   logger.warn(
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Discrete(7)

# %%
## %matplotlib inline
import time # for tracking time

tStart = time.time()

# first create an instance of the TpgTrainer
# this creates the whole population and everything
# teamPopSize should realistically be at-least 100

customConfig = DefaultConfiguration()
customConfig.teamPopSize = 20
customConfig.isRampantMutationEnabled = False

trainer = Trainer(actions=range(7), config=customConfig) 

curScores = [] # hold scores in a generation
summaryScores = [] # record score summaries for each gen (min, max, avg)

# 5 generations isn't much (not even close), but some improvements
# should be seen.
for gen in range(5): # generation loop
    curScores = [] # new list per gen
    
    agents = trainer.getAgents()
    
    while True: # loop to go through agents
        teamNum = len(agents)
        agent = agents.pop()
        if agent is None:
            break # no more agents, so proceed to next gen
        
        state = env.reset()[0] # get initial state and prep environment
        score = 0
        for i in range(500): # run episodes that last 500 frames
            show_state(env, i, 'Assault', 'Gen #' + str(gen) + 
                       ', Team #' + str(teamNum) +
                       ', Score: ' + str(score)) # render env
            
            # must transform to at-least int-32 (for my getState to bitshift correctly)
            # print(state)
            act = agent.act(getState(np.array(state, dtype=np.int32))) 

            # feedback from env
            #print("act", act[0])
            

            test = env.step(act[0])

           
            state, reward, isTerminated, isTruncated, debug = env.step(act[0])
            
            score += reward # accumulate reward in score
            if isTerminated or isTruncated:
                break # end early if losing state

        agent.reward(score) # must reward agent (if didn't already score)
            
        curScores.append(score) # store score
        
        if len(agents) == 0:
            break
            
    # at end of generation, make summary of scores
    summaryScores.append((min(curScores), max(curScores),
                    sum(curScores)/len(curScores))) # min, max, avg
    trainer.evolve()
    
#clear_output(wait=True)
print('Time Taken (Hours): ' + str((time.time() - tStart)/3600))
print('Results:\nMin, Max, Avg')
for result in summaryScores:
    print(result[0],result[1],result[2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 66
#      63     # at end of generation, make summary of scores
#      64     summaryScores.append((min(curScores), max(curScores),
#      65                     sum(curScores)/len(curScores))) # min, max, avg
# ---> 66     trainer.evolve()
#      68 #clear_output(wait=True)
#      69 print('Time Taken (Hours): ' + str((time.time() - tStart)/3600))
#
# File ~/Desktop/tpg/PyTPG/tpg/trainer.py:166, in Trainer.evolve(self, tasks, multiTaskType)
#     164 self.saveFitnessStats() # save fitness stats
#     165 self.select() # select individuals to keep
# --> 166 self.generate() # create new individuals from those kept
#     167 self.nextEpoch()
#
# File ~/Desktop/tpg/PyTPG/tpg/trainer.py:347, in Trainer.generate(self)
#     345 actProgMut = (self.generation % 20 >= 10)
#     346 # then mutates
# --> 347 child.mutate(self.config, self.generation, oLearners, self.actions, self.actionLengths, oTeams,
#     348             actProgMut, inputs=inputs, outputs=outputs)
#     350 self.teams.append(child)
#     351 self.rootTeams.append(child)
#
# File ~/Desktop/tpg/PyTPG/tpg/team.py:130, in Team.mutate(self, config, generation, allLearners, actionCodes, actionLengths, allTeams, progMutFlag, inputs, outputs)
#     125 oLearners = list(self.learners)
#     127 # Determine if Rampant Mutation is enabled
#     128 # and if so check if this is a rampant mutation round
#     129 shouldRampantlyMutate = (config.isRampantMutationEnabled and
# --> 130                          generation % config.rampantMutationEveryXGenerations == 0)
#     132 for learner in oLearners:
#     133     if flip(config.pMutLrn) or shouldRampantlyMutate:
#
# AttributeError: 'DefaultConfiguration' object has no attribute 'rampantmutationEveryXGenerations'
