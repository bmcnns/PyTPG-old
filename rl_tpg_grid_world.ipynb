# %%
from tpg.trainer import Trainer
from tpg.agent import Agent
from tpg.gridworld import GridWorld
from tpg.qlearner import QLearner
from tpg.memory import Memory, get_memory
from tpg.configurations import DefaultConfiguration
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from pprint import pprint

# %%
width = 5
height = 5
targetCell = (4, 4)
walls = [(2, 2), (3, 2), (1, 4), (4, 3)]  # Define wall positions
epsilon = 0.25
env = GridWorld(width, height, targetCell, walls)

# %%
customConfig = DefaultConfiguration()
customConfig.teamPopSize = 100
customConfig.memorySize = 4

numGenerations = 100

memory = Memory(customConfig.memorySize)

# %%
qLearner = QLearner(4, 4, 0.8, 0.001)
epsilon = 0.15

# %%
def detect_changes(predecessor, successor):
    return [1 if pred != succ else 0 for pred, succ in zip(predecessor, successor)]

list_a = [0, 0, 0, 0]
list_b = [1, 0, 1, 1]

diff = detect_changes(list_a, list_b)
print(diff)
# Out:
# [1, 0, 1, 1]

# %%
from pprint import pprint
import ipdb

trainer = Trainer(actions=range(5), config=customConfig)
memory.memory_reset()

rewardStats = []
numStepsStats= []

#print("Registers:")
#print(get_memory().registers)
previousState = memory.registers

print(numGenerations)
print(customConfig.teamPopSize)

for generation in range(numGenerations):
    
    rewards = [] # new list every gen
    numSteps = [] # new list every gen
    
    agents = trainer.getAgents()
    
    while True:     
        teamNum = len(agents)
        agent = agents.pop()
                
        if agent is None:
            break # no more agents, proceed to next gen
        
        env.reset()
        
        
        score = 0
        
        
        i = 0
        
        print(f"Gen #{generation}, Team #{teamNum}")

        memory.step = 0
        while not env.isTerminal() and i < 500:
            
            
            memory.step += 1
            
            i += 1
            
            #env.display()      
        
            
            memory.buffer_reset()
            
            
            #print("Pre-update global memory")
            #print(get_memory().registers)
                
            programs = agent.getPrograms()
            
            winning_program_id = agent.act(env.getState())
            
            #get_memory().display()
            
            #print(programs, "Winner:", winning_program_id)
            
            before_memory_update = memory.registers
            
            memory.commit(program_id=winning_program_id)
            
            after_memory_update = memory.registers
            
            nextState = detect_changes(before_memory_update, after_memory_update)
            #print("Changes:")
            #print(nextState)
            
            #print("Updated global memory:")
            
            #print(get_memory().registers)
            #print()
            
            #if tpg_response is None:
             #   action = 
            #else:
            #    action = np.argmax(tpg_response)
            
            if generation < 2:
                action = np.random.randint(4)
            else:
                if np.random.random() < epsilon:
                    action = np.random.randint(4)
                else:
                    action = qLearner.predict(previousState).argmax()
                    
            _, reward = env.step(action)
            
            score += reward
            
            #print(previousState, action, reward, nextState)
            
            if generation >= 2:
                """
                print("Previous state")
                print(previousState)
                print("Next state")
                print(nextState)
                print(f"Action selected: {action}, Reward: {reward}")
                """
                qLearner.train(previousState, nextState, reward, action)
            
            previousState = nextState
            
        
        if i == 500:
            print("Ran out of turns... giving up")
        
       
        #get_memory().display()
        #print(get_memory().registers)
            
        agent.reward(score)
        
        rewards.append(score)
        numSteps.append(i)
        
        print(f"Finished after {i} steps with cumulative reward {score}, writes: {memory.writeCount}...")
        # env.display()
        
        if len(agents) == 0:
            break
    
    rewardStats.append((min(rewards), max(rewards), sum(rewards)/len(rewards)))
    numStepsStats.append((min(numSteps), max(numSteps), sum(numSteps)/len(numSteps)))
    trainer.evolve()
    
    memory.generation += 1
# Out:
# 100
# 100
# Gen #0, Team #100
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -160.0, writes: 500...
# Gen #0, Team #99
# Finished after 51 steps with cumulative reward 81.0, writes: 551...
# Gen #0, Team #98
# Finished after 138 steps with cumulative reward 54.0, writes: 689...
# Gen #0, Team #97
# Finished after 54 steps with cumulative reward 74.0, writes: 743...
# Gen #0, Team #96
# Finished after 326 steps with cumulative reward -16.0, writes: 743...
# Gen #0, Team #95
# Finished after 260 steps with cumulative reward 8.0, writes: 1003...
# Gen #0, Team #94
# Finished after 332 steps with cumulative reward 0.0, writes: 1335...
# Gen #0, Team #93
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -181.0, writes: 1793...
# Gen #0, Team #92
# Finished after 271 steps with cumulative reward 15.0, writes: 2064...
# Gen #0, Team #91
# Finished after 326 steps with cumulative reward 10.0, writes: 2390...
# Gen #0, Team #90
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -169.0, writes: 2890...
# Gen #0, Team #89
# Finished after 465 steps with cumulative reward -61.0, writes: 3355...
# Gen #0, Team #88
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -230.0, writes: 3855...
# Gen #0, Team #87
# Finished after 112 steps with cumulative reward 62.0, writes: 3967...
# Gen #0, Team #86
# Finished after 143 steps with cumulative reward 41.0, writes: 4110...
# Gen #0, Team #85
# Finished after 87 steps with cumulative reward 77.0, writes: 4197...
# Gen #0, Team #84
# Finished after 163 steps with cumulative reward 47.0, writes: 4360...
# Gen #0, Team #83
# Finished after 26 steps with cumulative reward 94.0, writes: 4386...
# Gen #0, Team #82
# Finished after 157 steps with cumulative reward 55.0, writes: 4543...
# Gen #0, Team #81
# /home/bryce/Desktop/PyTPG/tpg/program.py:77: RuntimeWarning: overflow encountered in double_scalars
#   regs[dest] = x*2
# Finished after 167 steps with cumulative reward 25.0, writes: 4710...
# Gen #0, Team #80
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -155.0, writes: 5210...
# Gen #0, Team #79
# Finished after 437 steps with cumulative reward -39.0, writes: 5647...
# Gen #0, Team #78
# Finished after 179 steps with cumulative reward 45.0, writes: 5826...
# Gen #0, Team #77
# Finished after 14 steps with cumulative reward 98.0, writes: 5828...
# Gen #0, Team #76
# Finished after 234 steps with cumulative reward -12.0, writes: 6062...
# Gen #0, Team #75
# Finished after 284 steps with cumulative reward -16.0, writes: 6346...
# Gen #0, Team #74
# Finished after 452 steps with cumulative reward -32.0, writes: 6798...
# Gen #0, Team #73
# Finished after 322 steps with cumulative reward 2.0, writes: 7120...
# Gen #0, Team #72
# Finished after 121 steps with cumulative reward 53.0, writes: 7241...
# Gen #0, Team #71
# Finished after 293 steps with cumulative reward 7.0, writes: 7534...
# Gen #0, Team #70
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -138.0, writes: 8034...
# Gen #0, Team #69
# Finished after 216 steps with cumulative reward 34.0, writes: 8250...
# Gen #0, Team #68
# Finished after 101 steps with cumulative reward 69.0, writes: 8351...
# Gen #0, Team #67
# Finished after 318 steps with cumulative reward -8.0, writes: 8669...
# Gen #0, Team #66
# Finished after 156 steps with cumulative reward 44.0, writes: 8825...
# Gen #0, Team #65
# Finished after 49 steps with cumulative reward 79.0, writes: 8874...
# Gen #0, Team #64
# Finished after 245 steps with cumulative reward 11.0, writes: 9119...
# Gen #0, Team #63
# Finished after 88 steps with cumulative reward 74.0, writes: 9207...
# Gen #0, Team #62
# Finished after 102 steps with cumulative reward 66.0, writes: 9309...
# Gen #0, Team #61
# Finished after 256 steps with cumulative reward 18.0, writes: 9565...
# Gen #0, Team #60
# Finished after 85 steps with cumulative reward 69.0, writes: 9650...
# Gen #0, Team #59
# Finished after 43 steps with cumulative reward 85.0, writes: 9686...
# Gen #0, Team #58
# Finished after 494 steps with cumulative reward -58.0, writes: 10180...
# Gen #0, Team #57
# Finished after 37 steps with cumulative reward 91.0, writes: 10217...
# Gen #0, Team #56
# Finished after 122 steps with cumulative reward 48.0, writes: 10339...
# Gen #0, Team #55
# Finished after 53 steps with cumulative reward 85.0, writes: 10392...
# Gen #0, Team #54
# Finished after 180 steps with cumulative reward 38.0, writes: 10572...
# Gen #0, Team #53
# Finished after 37 steps with cumulative reward 87.0, writes: 10572...
# Gen #0, Team #52
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -138.0, writes: 11072...
# Gen #0, Team #51
# Finished after 64 steps with cumulative reward 74.0, writes: 11136...
# Gen #0, Team #50
# Finished after 68 steps with cumulative reward 82.0, writes: 11204...
# Gen #0, Team #49
# Finished after 101 steps with cumulative reward 73.0, writes: 11305...
# Gen #0, Team #48
# Finished after 195 steps with cumulative reward 41.0, writes: 11500...
# Gen #0, Team #47
# Finished after 150 steps with cumulative reward 42.0, writes: 11650...
# Gen #0, Team #46
# Finished after 15 steps with cumulative reward 93.0, writes: 11658...
# Gen #0, Team #45
# Finished after 254 steps with cumulative reward 4.0, writes: 11912...
# Gen #0, Team #44
# Finished after 181 steps with cumulative reward 53.0, writes: 12093...
# Gen #0, Team #43
# Finished after 160 steps with cumulative reward 52.0, writes: 12253...
# Gen #0, Team #42
# Finished after 293 steps with cumulative reward 5.0, writes: 12546...
# Gen #0, Team #41
# Finished after 66 steps with cumulative reward 88.0, writes: 12597...
# Gen #0, Team #40
# Finished after 90 steps with cumulative reward 76.0, writes: 12687...
# Gen #0, Team #39
# Finished after 390 steps with cumulative reward -24.0, writes: 13077...
# Gen #0, Team #38
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -164.0, writes: 13577...
# Gen #0, Team #37
# Finished after 114 steps with cumulative reward 58.0, writes: 13691...
# Gen #0, Team #36
# Finished after 28 steps with cumulative reward 96.0, writes: 13719...
# Gen #0, Team #35
# Finished after 346 steps with cumulative reward -8.0, writes: 14065...
# Gen #0, Team #34
# Finished after 374 steps with cumulative reward -20.0, writes: 14439...
# Gen #0, Team #33
# Finished after 166 steps with cumulative reward 50.0, writes: 14605...
# Gen #0, Team #32
# Finished after 92 steps with cumulative reward 76.0, writes: 14697...
# Gen #0, Team #31
# Finished after 396 steps with cumulative reward -40.0, writes: 15093...
# Gen #0, Team #30
# Finished after 150 steps with cumulative reward 56.0, writes: 15243...
# Gen #0, Team #29
# Finished after 298 steps with cumulative reward 4.0, writes: 15541...
# Gen #0, Team #28
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -158.0, writes: 15541...
# Gen #0, Team #27
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -180.0, writes: 15541...
# Gen #0, Team #26
# Finished after 225 steps with cumulative reward 23.0, writes: 15766...
# Gen #0, Team #25
# Finished after 186 steps with cumulative reward 32.0, writes: 15952...
# Gen #0, Team #24
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -194.0, writes: 16452...
# Gen #0, Team #23
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -148.0, writes: 16952...
# Gen #0, Team #22
# Finished after 176 steps with cumulative reward 30.0, writes: 17128...
# Gen #0, Team #21
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -167.0, writes: 17628...
# Gen #0, Team #20
# Finished after 104 steps with cumulative reward 60.0, writes: 17732...
# Gen #0, Team #19
# Finished after 121 steps with cumulative reward 59.0, writes: 17853...
# Gen #0, Team #18
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -173.0, writes: 18353...
# Gen #0, Team #17
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -160.0, writes: 18853...
# Gen #0, Team #16
# Finished after 471 steps with cumulative reward -87.0, writes: 19324...
# Gen #0, Team #15
# Finished after 30 steps with cumulative reward 84.0, writes: 19354...
# Gen #0, Team #14
# Finished after 111 steps with cumulative reward 59.0, writes: 19465...
# Gen #0, Team #13
# Finished after 77 steps with cumulative reward 77.0, writes: 19542...
# Gen #0, Team #12
# Finished after 210 steps with cumulative reward 28.0, writes: 19752...
# Gen #0, Team #11
# Finished after 31 steps with cumulative reward 93.0, writes: 19783...
# Gen #0, Team #10
# Finished after 459 steps with cumulative reward -21.0, writes: 20242...
# Gen #0, Team #9
# Finished after 34 steps with cumulative reward 88.0, writes: 20276...
# Gen #0, Team #8
# Finished after 379 steps with cumulative reward -9.0, writes: 20655...
# Gen #0, Team #7
# Finished after 61 steps with cumulative reward 85.0, writes: 20716...
# Gen #0, Team #6
# Finished after 152 steps with cumulative reward 68.0, writes: 20868...
# Gen #0, Team #5
# Finished after 266 steps with cumulative reward -14.0, writes: 21134...
# /home/bryce/Desktop/PyTPG/tpg/program.py:75: RuntimeWarning: overflow encountered in double_scalars
#   regs[dest] = x-y
# /home/bryce/Desktop/PyTPG/tpg/program.py:73: RuntimeWarning: overflow encountered in double_scalars
#   regs[dest] = x+y
# Gen #0, Team #4
# Finished after 45 steps with cumulative reward 85.0, writes: 21179...
# Gen #0, Team #3
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -185.0, writes: 21679...
# Gen #0, Team #2
# Finished after 180 steps with cumulative reward 44.0, writes: 21859...
# Gen #0, Team #1
# Finished after 292 steps with cumulative reward 2.0, writes: 22151...
# Gen #1, Team #100
# Finished after 294 steps with cumulative reward 2.0, writes: 22445...
# Gen #1, Team #99
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -148.0, writes: 22945...
# Gen #1, Team #98
# Finished after 143 steps with cumulative reward 55.0, writes: 23088...
# Gen #1, Team #97
# Finished after 330 steps with cumulative reward -20.0, writes: 23418...
# Gen #1, Team #96
# Finished after 212 steps with cumulative reward 36.0, writes: 23630...
# Gen #1, Team #95
# Finished after 90 steps with cumulative reward 64.0, writes: 23720...
# Gen #1, Team #94
# Finished after 58 steps with cumulative reward 76.0, writes: 23778...
# Gen #1, Team #93
# Finished after 117 steps with cumulative reward 53.0, writes: 23895...
# Gen #1, Team #92
# Finished after 145 steps with cumulative reward 55.0, writes: 24040...
# Gen #1, Team #91
# Finished after 151 steps with cumulative reward 55.0, writes: 24040...
# Gen #1, Team #90
# Finished after 93 steps with cumulative reward 65.0, writes: 24133...
# Gen #1, Team #89
# Finished after 321 steps with cumulative reward 17.0, writes: 24454...
# Gen #1, Team #88
# Finished after 242 steps with cumulative reward 12.0, writes: 24696...
# Gen #1, Team #87
# Finished after 38 steps with cumulative reward 92.0, writes: 24734...
# Gen #1, Team #86
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -164.0, writes: 25234...
# Gen #1, Team #85
# Finished after 171 steps with cumulative reward 31.0, writes: 25405...
# Gen #1, Team #84
# Finished after 338 steps with cumulative reward -6.0, writes: 25743...
# Gen #1, Team #83
# Finished after 58 steps with cumulative reward 82.0, writes: 25801...
# Gen #1, Team #82
# Finished after 73 steps with cumulative reward 85.0, writes: 25874...
# Gen #1, Team #81
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -187.0, writes: 26374...
# Gen #1, Team #80
# Finished after 45 steps with cumulative reward 75.0, writes: 26419...
# Gen #1, Team #79
# Finished after 162 steps with cumulative reward 34.0, writes: 26581...
# Gen #1, Team #78
# Finished after 55 steps with cumulative reward 79.0, writes: 26636...
# Gen #1, Team #77
# Finished after 406 steps with cumulative reward -38.0, writes: 27042...
# Gen #1, Team #76
# Finished after 396 steps with cumulative reward -28.0, writes: 27438...
# Gen #1, Team #75
# Finished after 122 steps with cumulative reward 54.0, writes: 27560...
# Gen #1, Team #74
# Finished after 360 steps with cumulative reward -12.0, writes: 27920...
# Gen #1, Team #73
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -182.0, writes: 28420...
# Gen #1, Team #72
# Finished after 231 steps with cumulative reward 31.0, writes: 28651...
# Gen #1, Team #71
# Finished after 78 steps with cumulative reward 78.0, writes: 28729...
# Gen #1, Team #70
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -177.0, writes: 29229...
# Gen #1, Team #69
# Finished after 357 steps with cumulative reward -7.0, writes: 29586...
# Gen #1, Team #68
# Finished after 76 steps with cumulative reward 78.0, writes: 29662...
# Gen #1, Team #67
# Finished after 200 steps with cumulative reward 24.0, writes: 29862...
# Gen #1, Team #66
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -162.0, writes: 30362...
# Gen #1, Team #65
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -138.0, writes: 30862...
# Gen #1, Team #64
# Finished after 34 steps with cumulative reward 90.0, writes: 30896...
# Gen #1, Team #63
# Finished after 37 steps with cumulative reward 87.0, writes: 30933...
# Gen #1, Team #62
# Finished after 28 steps with cumulative reward 94.0, writes: 30961...
# Gen #1, Team #61
# Finished after 190 steps with cumulative reward 26.0, writes: 31151...
# Gen #1, Team #60
# Finished after 185 steps with cumulative reward 55.0, writes: 31336...
# Gen #1, Team #59
# Finished after 128 steps with cumulative reward 64.0, writes: 31464...
# Gen #1, Team #58
# Finished after 50 steps with cumulative reward 88.0, writes: 31514...
# Gen #1, Team #57
# Finished after 86 steps with cumulative reward 80.0, writes: 31600...
# Gen #1, Team #56
# Finished after 253 steps with cumulative reward 15.0, writes: 31853...
# Gen #1, Team #55
# Finished after 279 steps with cumulative reward 15.0, writes: 32132...
# Gen #1, Team #54
# Finished after 153 steps with cumulative reward 51.0, writes: 32285...
# Gen #1, Team #53
# Finished after 84 steps with cumulative reward 74.0, writes: 32369...
# Gen #1, Team #52
# Finished after 88 steps with cumulative reward 68.0, writes: 32457...
# Gen #1, Team #51
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -142.0, writes: 32957...
# Gen #1, Team #50
# Finished after 454 steps with cumulative reward -68.0, writes: 33411...
# Gen #1, Team #49
# Finished after 291 steps with cumulative reward 3.0, writes: 33702...
# Gen #1, Team #48
# Finished after 294 steps with cumulative reward 20.0, writes: 33996...
# Gen #1, Team #47
# Finished after 34 steps with cumulative reward 88.0, writes: 34030...
# Gen #1, Team #46
# Finished after 379 steps with cumulative reward -41.0, writes: 34409...
# Gen #1, Team #45
# Finished after 201 steps with cumulative reward 15.0, writes: 34610...
# Gen #1, Team #44
# Finished after 136 steps with cumulative reward 66.0, writes: 34746...
# Gen #1, Team #43
# Finished after 57 steps with cumulative reward 83.0, writes: 34803...
# Gen #1, Team #42
# Finished after 41 steps with cumulative reward 85.0, writes: 34844...
# Gen #1, Team #41
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -179.0, writes: 35344...
# Gen #1, Team #40
# Finished after 30 steps with cumulative reward 88.0, writes: 35374...
# Gen #1, Team #39
# Finished after 22 steps with cumulative reward 90.0, writes: 35396...
# Gen #1, Team #38
# Finished after 44 steps with cumulative reward 86.0, writes: 35440...
# Gen #1, Team #37
# Finished after 390 steps with cumulative reward -36.0, writes: 35830...
# Gen #1, Team #36
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -153.0, writes: 36330...
# Gen #1, Team #35
# Finished after 211 steps with cumulative reward 15.0, writes: 36541...
# Gen #1, Team #34
# Finished after 153 steps with cumulative reward 59.0, writes: 36694...
# Gen #1, Team #33
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -162.0, writes: 37194...
# Gen #1, Team #32
# Finished after 159 steps with cumulative reward 63.0, writes: 37194...
# Gen #1, Team #31
# Finished after 103 steps with cumulative reward 59.0, writes: 37297...
# Gen #1, Team #30
# Finished after 357 steps with cumulative reward -37.0, writes: 37654...
# Gen #1, Team #29
# Finished after 121 steps with cumulative reward 61.0, writes: 37775...
# Gen #1, Team #28
# Finished after 137 steps with cumulative reward 65.0, writes: 37912...
# Gen #1, Team #27
# Finished after 169 steps with cumulative reward 43.0, writes: 38081...
# Gen #1, Team #26
# Finished after 110 steps with cumulative reward 54.0, writes: 38191...
# Gen #1, Team #25
# Finished after 377 steps with cumulative reward -19.0, writes: 38565...
# Gen #1, Team #24
# Finished after 16 steps with cumulative reward 98.0, writes: 38581...
# Gen #1, Team #23
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -159.0, writes: 39081...
# Gen #1, Team #22
# Finished after 128 steps with cumulative reward 60.0, writes: 39209...
# Gen #1, Team #21
# Finished after 106 steps with cumulative reward 68.0, writes: 39315...
# Gen #1, Team #20
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -173.0, writes: 39315...
# Gen #1, Team #19
# Finished after 41 steps with cumulative reward 87.0, writes: 39356...
# Gen #1, Team #18
# Finished after 498 steps with cumulative reward -70.0, writes: 39854...
# Gen #1, Team #17
# Finished after 97 steps with cumulative reward 61.0, writes: 39951...
# Gen #1, Team #16
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -157.0, writes: 40451...
# Gen #1, Team #15
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -159.0, writes: 40951...
# Gen #1, Team #14
# Finished after 100 steps with cumulative reward 62.0, writes: 41051...
# Gen #1, Team #13
# Finished after 191 steps with cumulative reward 31.0, writes: 41242...
# Gen #1, Team #12
# Finished after 34 steps with cumulative reward 94.0, writes: 41276...
# Gen #1, Team #11
# Finished after 256 steps with cumulative reward 16.0, writes: 41532...
# Gen #1, Team #10
# Finished after 306 steps with cumulative reward 16.0, writes: 41838...
# Gen #1, Team #9
# Finished after 274 steps with cumulative reward 6.0, writes: 42112...
# Gen #1, Team #8
# Finished after 40 steps with cumulative reward 88.0, writes: 42152...
# Gen #1, Team #7
# Finished after 379 steps with cumulative reward 3.0, writes: 42531...
# Gen #1, Team #6
# Finished after 43 steps with cumulative reward 91.0, writes: 42574...
# Gen #1, Team #5
# Finished after 59 steps with cumulative reward 81.0, writes: 42633...
# Gen #1, Team #4
# Finished after 230 steps with cumulative reward 34.0, writes: 42863...
# Gen #1, Team #3
# Finished after 82 steps with cumulative reward 76.0, writes: 42945...
# Gen #1, Team #2
# Finished after 48 steps with cumulative reward 80.0, writes: 42993...
# Gen #1, Team #1
# Finished after 232 steps with cumulative reward 28.0, writes: 43225...
# Gen #2, Team #101
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -428.0, writes: 43725...
# Gen #2, Team #100
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -431.0, writes: 44225...
# Gen #2, Team #99
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -430.0, writes: 44725...
# Gen #2, Team #98
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -434.0, writes: 45225...
# Gen #2, Team #97
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -434.0, writes: 45725...
# Gen #2, Team #96
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -336.0, writes: 46225...
# Gen #2, Team #95
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -108.0, writes: 46725...
# Gen #2, Team #94
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -398.0, writes: 47225...
# Gen #2, Team #93
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -424.0, writes: 47725...
# Gen #2, Team #92
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -315.0, writes: 48225...
# Gen #2, Team #91
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -416.0, writes: 48725...
# Gen #2, Team #90
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -448.0, writes: 49225...
# Gen #2, Team #89
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -430.0, writes: 49725...
# Gen #2, Team #88
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -321.0, writes: 50225...
# Gen #2, Team #87
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -270.0, writes: 50725...
# Gen #2, Team #86
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -149.0, writes: 51225...
# Gen #2, Team #85
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -440.0, writes: 51725...
# Gen #2, Team #84
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -176.0, writes: 52225...
# Gen #2, Team #83
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -381.0, writes: 52725...
# Gen #2, Team #82
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -416.0, writes: 53225...
# Gen #2, Team #81
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -450.0, writes: 53725...
# Gen #2, Team #80
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -273.0, writes: 54225...
# Gen #2, Team #79
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -273.0, writes: 54725...
# Gen #2, Team #78
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -226.0, writes: 55225...
# Gen #2, Team #77
# Finished after 224 steps with cumulative reward 4.0, writes: 55449...
# Gen #2, Team #76
# Finished after 233 steps with cumulative reward -1.0, writes: 55682...
# Gen #2, Team #75
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -448.0, writes: 56182...
# Gen #2, Team #74
# Finished after 85 steps with cumulative reward 31.0, writes: 56267...
# Gen #2, Team #73
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -320.0, writes: 56767...
# Gen #2, Team #72
# Finished after 307 steps with cumulative reward -161.0, writes: 57074...
# Gen #2, Team #71
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -422.0, writes: 57574...
# Gen #2, Team #70
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -261.0, writes: 58074...
# Gen #2, Team #69
# Finished after 120 steps with cumulative reward 44.0, writes: 58194...
# Gen #2, Team #68
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -389.0, writes: 58694...
# Gen #2, Team #67
# Finished after 133 steps with cumulative reward 5.0, writes: 58827...
# Gen #2, Team #66
# Finished after 263 steps with cumulative reward -133.0, writes: 59090...
# Gen #2, Team #65
# Finished after 286 steps with cumulative reward -132.0, writes: 59376...
# Gen #2, Team #64
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -356.0, writes: 59876...
# Gen #2, Team #63
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -376.0, writes: 60366...
# Gen #2, Team #62
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -283.0, writes: 60866...
# Gen #2, Team #61
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -449.0, writes: 61366...
# Gen #2, Team #60
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -279.0, writes: 61866...
# Gen #2, Team #59
# Finished after 458 steps with cumulative reward -212.0, writes: 62324...
# Gen #2, Team #58
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -327.0, writes: 62824...
# Gen #2, Team #57
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -243.0, writes: 63324...
# Gen #2, Team #56
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -248.0, writes: 63824...
# Gen #2, Team #55
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -450.0, writes: 64324...
# Gen #2, Team #54
# Finished after 379 steps with cumulative reward -83.0, writes: 64703...
# Gen #2, Team #53
# Finished after 272 steps with cumulative reward -46.0, writes: 64975...
# Gen #2, Team #52
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -288.0, writes: 65475...
# Gen #2, Team #51
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -336.0, writes: 65975...
# Gen #2, Team #50
# Finished after 388 steps with cumulative reward -80.0, writes: 66363...
# Gen #2, Team #49
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -402.0, writes: 66863...
# Gen #2, Team #48
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -192.0, writes: 67363...
# Gen #2, Team #47
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -451.0, writes: 67863...
# Gen #2, Team #46
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -352.0, writes: 68363...
# Gen #2, Team #45
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -416.0, writes: 68863...
# Gen #2, Team #44
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -383.0, writes: 69363...
# Gen #2, Team #43
# Finished after 434 steps with cumulative reward -124.0, writes: 69797...
# Gen #2, Team #42
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -348.0, writes: 69797...
# Gen #2, Team #41
# Finished after 60 steps with cumulative reward 68.0, writes: 69857...
# Gen #2, Team #40
# Finished after 429 steps with cumulative reward -203.0, writes: 70286...
# Gen #2, Team #39
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -166.0, writes: 70786...
# Gen #2, Team #38
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -305.0, writes: 71286...
# Gen #2, Team #37
# Finished after 360 steps with cumulative reward -110.0, writes: 71646...
# Gen #2, Team #36
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -350.0, writes: 72146...
# Gen #2, Team #35
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -378.0, writes: 72646...
# Gen #2, Team #34
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -406.0, writes: 73146...
# Gen #2, Team #33
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -412.0, writes: 73646...
# Gen #2, Team #32
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -395.0, writes: 74146...
# Gen #2, Team #31
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -452.0, writes: 74646...
# Gen #2, Team #30
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -278.0, writes: 75146...
# Gen #2, Team #29
# Finished after 361 steps with cumulative reward -101.0, writes: 75507...
# Gen #2, Team #28
# Finished after 381 steps with cumulative reward -215.0, writes: 75888...
# Gen #2, Team #27
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -361.0, writes: 76388...
# Gen #2, Team #26
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -326.0, writes: 76888...
# Gen #2, Team #25
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -349.0, writes: 77388...
# Gen #2, Team #24
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -390.0, writes: 77888...
# Gen #2, Team #23
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -412.0, writes: 78388...
# Gen #2, Team #22
# Finished after 93 steps with cumulative reward 41.0, writes: 78481...
# Gen #2, Team #21
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -410.0, writes: 78981...
# Gen #2, Team #20
# Finished after 156 steps with cumulative reward 6.0, writes: 79137...
# Gen #2, Team #19
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -310.0, writes: 79637...
# Gen #2, Team #18
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -375.0, writes: 79637...
# Gen #2, Team #17
# Finished after 210 steps with cumulative reward -12.0, writes: 79847...
# Gen #2, Team #16
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -306.0, writes: 80347...
# Gen #2, Team #15
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -266.0, writes: 80847...
# Gen #2, Team #14
# Finished after 295 steps with cumulative reward -141.0, writes: 81142...
# Gen #2, Team #13
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -352.0, writes: 81642...
# Gen #2, Team #12
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -438.0, writes: 82142...
# Gen #2, Team #11
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -444.0, writes: 82642...
# Gen #2, Team #10
# Finished after 112 steps with cumulative reward 48.0, writes: 82754...
# Gen #2, Team #9
# Finished after 284 steps with cumulative reward -92.0, writes: 83038...
# Gen #2, Team #8
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -233.0, writes: 83538...
# Gen #2, Team #7
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -442.0, writes: 84038...
# Gen #2, Team #6
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -316.0, writes: 84538...
# Gen #2, Team #5
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -236.0, writes: 85038...
# Gen #2, Team #4
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -327.0, writes: 85538...
# Gen #2, Team #3
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -304.0, writes: 86038...
# Gen #2, Team #2
# Finished after 11 steps with cumulative reward 99.0, writes: 86049...
# Gen #2, Team #1
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -270.0, writes: 86549...
# Gen #3, Team #100
# Finished after 467 steps with cumulative reward -287.0, writes: 87016...
# Gen #3, Team #99
# Finished after 181 steps with cumulative reward -33.0, writes: 87197...
# Gen #3, Team #98
# Finished after 422 steps with cumulative reward -210.0, writes: 87619...
# Gen #3, Team #97
# Finished after 478 steps with cumulative reward -294.0, writes: 88097...
# Gen #3, Team #96
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -181.0, writes: 88597...
# Gen #3, Team #95
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -336.0, writes: 89097...
# Gen #3, Team #94
# Finished after 107 steps with cumulative reward 37.0, writes: 89204...
# Gen #3, Team #93
# Finished after 469 steps with cumulative reward -239.0, writes: 89673...
# Gen #3, Team #92
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -376.0, writes: 90173...
# Gen #3, Team #91
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -277.0, writes: 90673...
# Gen #3, Team #90
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -231.0, writes: 91173...
# Gen #3, Team #89
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -429.0, writes: 91673...
# Gen #3, Team #88
# Finished after 486 steps with cumulative reward -240.0, writes: 92159...
# Gen #3, Team #87
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -402.0, writes: 92659...
# Gen #3, Team #86
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -248.0, writes: 93159...
# Gen #3, Team #85
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -414.0, writes: 93659...
# Gen #3, Team #84
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -408.0, writes: 94159...
# Gen #3, Team #83
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -356.0, writes: 94659...
# Gen #3, Team #82
# Finished after 77 steps with cumulative reward 71.0, writes: 94736...
# Gen #3, Team #81
# Finished after 20 steps with cumulative reward 94.0, writes: 94756...
# Gen #3, Team #80
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -439.0, writes: 95256...
# Gen #3, Team #79
# Finished after 40 steps with cumulative reward 80.0, writes: 95296...
# Gen #3, Team #78
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -366.0, writes: 95796...
# Gen #3, Team #77
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -288.0, writes: 96296...
# Gen #3, Team #76
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -295.0, writes: 96796...
# Gen #3, Team #75
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -282.0, writes: 97296...
# Gen #3, Team #74
# Finished after 27 steps with cumulative reward 85.0, writes: 97323...
# Gen #3, Team #73
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -369.0, writes: 97823...
# Gen #3, Team #72
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -219.0, writes: 98323...
# Gen #3, Team #71
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -331.0, writes: 98823...
# Gen #3, Team #70
# Finished after 225 steps with cumulative reward -39.0, writes: 99048...
# Gen #3, Team #69
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -251.0, writes: 99548...
# Gen #3, Team #68
# Finished after 429 steps with cumulative reward -137.0, writes: 99977...
# Gen #3, Team #67
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -366.0, writes: 100477...
# Gen #3, Team #66
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -259.0, writes: 100977...
# Gen #3, Team #65
# Finished after 419 steps with cumulative reward -161.0, writes: 101396...
# Gen #3, Team #64
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -363.0, writes: 101896...
# Gen #3, Team #63
# Finished after 494 steps with cumulative reward -140.0, writes: 102390...
# Gen #3, Team #62
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -362.0, writes: 102890...
# Gen #3, Team #61
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -223.0, writes: 103390...
# Gen #3, Team #60
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -195.0, writes: 103890...
# Gen #3, Team #59
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -281.0, writes: 104390...
# Gen #3, Team #58
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -138.0, writes: 104890...
# Gen #3, Team #57
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -382.0, writes: 105390...
# Gen #3, Team #56
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -343.0, writes: 105890...
# Gen #3, Team #55
# Finished after 437 steps with cumulative reward -307.0, writes: 105890...
# Gen #3, Team #54
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -377.0, writes: 106390...
# Gen #3, Team #53
# Finished after 407 steps with cumulative reward -95.0, writes: 106797...
# Gen #3, Team #52
# Finished after 191 steps with cumulative reward -61.0, writes: 106988...
# Gen #3, Team #51
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -448.0, writes: 107488...
# Gen #3, Team #50
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -270.0, writes: 107988...
# Gen #3, Team #49
# Finished after 353 steps with cumulative reward -65.0, writes: 108341...
# Gen #3, Team #48
# Finished after 486 steps with cumulative reward -204.0, writes: 108827...
# Gen #3, Team #47
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -384.0, writes: 109327...
# Gen #3, Team #46
# Finished after 323 steps with cumulative reward -91.0, writes: 109650...
# Gen #3, Team #45
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -418.0, writes: 110150...
# Gen #3, Team #44
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -313.0, writes: 110650...
# Gen #3, Team #43
# Finished after 269 steps with cumulative reward -55.0, writes: 110919...
# Gen #3, Team #42
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -364.0, writes: 111419...
# Gen #3, Team #41
# Finished after 29 steps with cumulative reward 87.0, writes: 111448...
# Gen #3, Team #40
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -369.0, writes: 111948...
# Gen #3, Team #39
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -400.0, writes: 112448...
# Gen #3, Team #38
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -293.0, writes: 112948...
# Gen #3, Team #37
# Finished after 485 steps with cumulative reward -179.0, writes: 113433...
# Gen #3, Team #36
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -326.0, writes: 113933...
# Gen #3, Team #35
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -304.0, writes: 114433...
# Gen #3, Team #34
# Finished after 158 steps with cumulative reward -32.0, writes: 114591...
# Gen #3, Team #33
# Finished after 477 steps with cumulative reward -243.0, writes: 115068...
# Gen #3, Team #32
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -306.0, writes: 115568...
# Gen #3, Team #31
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -281.0, writes: 116068...
# Gen #3, Team #30
# Finished after 172 steps with cumulative reward -50.0, writes: 116240...
# Gen #3, Team #29
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -420.0, writes: 116740...
# Gen #3, Team #28
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -297.0, writes: 117240...
# Gen #3, Team #27
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -166.0, writes: 117740...
# Gen #3, Team #26
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -165.0, writes: 118240...
# Gen #3, Team #25
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -262.0, writes: 118740...
# Gen #3, Team #24
# Finished after 376 steps with cumulative reward -110.0, writes: 119116...
# Gen #3, Team #23
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -364.0, writes: 119616...
# Gen #3, Team #22
# Finished after 163 steps with cumulative reward 21.0, writes: 119779...
# Gen #3, Team #21
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -365.0, writes: 120279...
# Gen #3, Team #20
# Finished after 123 steps with cumulative reward 37.0, writes: 120402...
# Gen #3, Team #19
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -317.0, writes: 120902...
# Gen #3, Team #18
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -243.0, writes: 121402...
# Gen #3, Team #17
# Finished after 446 steps with cumulative reward -108.0, writes: 121848...
# Gen #3, Team #16
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -326.0, writes: 122348...
# Gen #3, Team #15
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -290.0, writes: 122848...
# Gen #3, Team #14
# Finished after 148 steps with cumulative reward -12.0, writes: 122996...
# Gen #3, Team #13
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -433.0, writes: 123496...
# Gen #3, Team #12
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -274.0, writes: 123996...
# Gen #3, Team #11
# Finished after 466 steps with cumulative reward -126.0, writes: 124462...
# Gen #3, Team #10
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -410.0, writes: 124962...
# Gen #3, Team #9
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -255.0, writes: 125462...
# Gen #3, Team #8
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -261.0, writes: 125962...
# Gen #3, Team #7
# Finished after 64 steps with cumulative reward 66.0, writes: 126026...
# Gen #3, Team #6
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -327.0, writes: 126526...
# Gen #3, Team #5
# Finished after 35 steps with cumulative reward 83.0, writes: 126561...
# Gen #3, Team #4
# Finished after 355 steps with cumulative reward -181.0, writes: 126916...
# Gen #3, Team #3
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -456.0, writes: 127416...
# Gen #3, Team #2
# Finished after 86 steps with cumulative reward 54.0, writes: 127502...
# Gen #3, Team #1
# Finished after 24 steps with cumulative reward 86.0, writes: 127526...
# Gen #4, Team #101
# Finished after 17 steps with cumulative reward 91.0, writes: 127543...
# Gen #4, Team #100
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -435.0, writes: 128043...
# Gen #4, Team #99
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -236.0, writes: 128543...
# Gen #4, Team #98
# Finished after 363 steps with cumulative reward -159.0, writes: 128906...
# Gen #4, Team #97
# Finished after 302 steps with cumulative reward -172.0, writes: 129208...
# Gen #4, Team #96
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -422.0, writes: 129708...
# Gen #4, Team #95
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -315.0, writes: 130208...
# Gen #4, Team #94
# Finished after 216 steps with cumulative reward -22.0, writes: 130424...
# Gen #4, Team #93
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -368.0, writes: 130924...
# Gen #4, Team #92
# Finished after 427 steps with cumulative reward -137.0, writes: 131351...
# Gen #4, Team #91
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -333.0, writes: 131851...
# Gen #4, Team #90
# Finished after 300 steps with cumulative reward -68.0, writes: 132151...
# Gen #4, Team #89
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -367.0, writes: 132651...
# Gen #4, Team #88
# Finished after 95 steps with cumulative reward 35.0, writes: 132746...
# Gen #4, Team #87
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -334.0, writes: 133246...
# Gen #4, Team #86
# Finished after 378 steps with cumulative reward -114.0, writes: 133624...
# Gen #4, Team #85
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -368.0, writes: 134124...
# Gen #4, Team #84
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -426.0, writes: 134588...
# Gen #4, Team #83
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -404.0, writes: 135088...
# Gen #4, Team #82
# Finished after 57 steps with cumulative reward 71.0, writes: 135145...
# Gen #4, Team #81
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -406.0, writes: 135645...
# Gen #4, Team #80
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -448.0, writes: 136145...
# Gen #4, Team #79
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -336.0, writes: 136645...
# Gen #4, Team #78
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -366.0, writes: 137145...
# Gen #4, Team #77
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -272.0, writes: 137634...
# Gen #4, Team #76
# Finished after 234 steps with cumulative reward -28.0, writes: 137868...
# Gen #4, Team #75
# Finished after 138 steps with cumulative reward -2.0, writes: 138006...
# Gen #4, Team #74
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -216.0, writes: 138506...
# Gen #4, Team #73
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -376.0, writes: 139006...
# Gen #4, Team #72
# Finished after 44 steps with cumulative reward 76.0, writes: 139050...
# Gen #4, Team #71
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -380.0, writes: 139550...
# Gen #4, Team #70
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -272.0, writes: 140050...
# Gen #4, Team #69
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -280.0, writes: 140550...
# Gen #4, Team #68
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -421.0, writes: 141050...
# Gen #4, Team #67
# Finished after 51 steps with cumulative reward 79.0, writes: 141101...
# Gen #4, Team #66
# Finished after 242 steps with cumulative reward -76.0, writes: 141343...
# Gen #4, Team #65
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -447.0, writes: 141843...
# Gen #4, Team #64
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -238.0, writes: 142343...
# Gen #4, Team #63
# Finished after 386 steps with cumulative reward -140.0, writes: 142729...
# Gen #4, Team #62
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -426.0, writes: 143229...
# Gen #4, Team #61
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -295.0, writes: 143729...
# Gen #4, Team #60
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -282.0, writes: 144229...
# Gen #4, Team #59
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -291.0, writes: 144729...
# Gen #4, Team #58
# Finished after 109 steps with cumulative reward 41.0, writes: 144838...
# Gen #4, Team #57
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -376.0, writes: 145338...
# Gen #4, Team #56
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -284.0, writes: 145838...
# Gen #4, Team #55
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -372.0, writes: 146338...
# Gen #4, Team #54
# Finished after 276 steps with cumulative reward -132.0, writes: 146614...
# Gen #4, Team #53
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -391.0, writes: 147114...
# Gen #4, Team #52
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -298.0, writes: 147614...
# Gen #4, Team #51
# Finished after 153 steps with cumulative reward 31.0, writes: 147767...
# Gen #4, Team #50
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -366.0, writes: 148267...
# Gen #4, Team #49
# Finished after 298 steps with cumulative reward -40.0, writes: 148565...
# Gen #4, Team #48
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -418.0, writes: 149065...
# Gen #4, Team #47
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -422.0, writes: 149565...
# Gen #4, Team #46
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -382.0, writes: 150065...
# Gen #4, Team #45
# Finished after 150 steps with cumulative reward 44.0, writes: 150215...
# Gen #4, Team #44
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -380.0, writes: 150715...
# Gen #4, Team #43
# Finished after 271 steps with cumulative reward -95.0, writes: 150986...
# Gen #4, Team #42
# Finished after 9 steps with cumulative reward 99.0, writes: 150995...
# Gen #4, Team #41
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -440.0, writes: 151495...
# Gen #4, Team #40
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -248.0, writes: 151995...
# Gen #4, Team #39
# Finished after 292 steps with cumulative reward -116.0, writes: 152287...
# Gen #4, Team #38
# ...
# Gen #24, Team #78
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -312.0, writes: 917382...
# Gen #24, Team #77
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -171.0, writes: 917882...
# Gen #24, Team #76
# Finished after 468 steps with cumulative reward -112.0, writes: 918350...
# Gen #24, Team #75
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -317.0, writes: 918850...
# Gen #24, Team #74
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -294.0, writes: 919350...
# Gen #24, Team #73
# Finished after 336 steps with cumulative reward -190.0, writes: 919686...
# Gen #24, Team #72
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -402.0, writes: 920186...
# Gen #24, Team #71
# Finished after 21 steps with cumulative reward 95.0, writes: 920207...
# Gen #24, Team #70
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -442.0, writes: 920705...
# Gen #24, Team #69
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -362.0, writes: 920896...
# Gen #24, Team #68
# Finished after 280 steps with cumulative reward -72.0, writes: 921176...
# Gen #24, Team #67
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -264.0, writes: 921676...
# Gen #24, Team #66
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -325.0, writes: 922176...
# Gen #24, Team #65
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -286.0, writes: 922676...
# Gen #24, Team #64
# Finished after 215 steps with cumulative reward -17.0, writes: 922891...
# Gen #24, Team #63
# Finished after 36 steps with cumulative reward 80.0, writes: 922927...
# Gen #24, Team #62
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -439.0, writes: 923427...
# Gen #24, Team #61
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -338.0, writes: 923927...
# Gen #24, Team #60
# Finished after 32 steps with cumulative reward 80.0, writes: 923959...
# Gen #24, Team #59
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -370.0, writes: 924459...
# Gen #24, Team #58
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -327.0, writes: 924959...
# Gen #24, Team #57
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -347.0, writes: 925459...
# Gen #24, Team #56
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -278.0, writes: 925959...
# Gen #24, Team #55
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -302.0, writes: 926459...
# Gen #24, Team #54
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -225.0, writes: 926959...
# Gen #24, Team #53
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -260.0, writes: 927459...
# Gen #24, Team #52
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -38.0, writes: 927959...
# Gen #24, Team #51
# Finished after 73 steps with cumulative reward 37.0, writes: 928032...
# Gen #24, Team #50
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -328.0, writes: 928532...
# Gen #24, Team #49
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -244.0, writes: 929021...
# Gen #24, Team #48
# Finished after 20 steps with cumulative reward 88.0, writes: 929041...
# Gen #24, Team #47
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -342.0, writes: 929541...
# Gen #24, Team #46
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -296.0, writes: 930041...
# Gen #24, Team #45
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -216.0, writes: 930541...
# Gen #24, Team #44
# Finished after 479 steps with cumulative reward -311.0, writes: 931020...
# Gen #24, Team #43
# Finished after 336 steps with cumulative reward -152.0, writes: 931356...
# Gen #24, Team #42
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -330.0, writes: 931856...
# Gen #24, Team #41
# Finished after 483 steps with cumulative reward -95.0, writes: 932339...
# Gen #24, Team #40
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -52.0, writes: 932839...
# Gen #24, Team #39
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -380.0, writes: 933339...
# Gen #24, Team #38
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -130.0, writes: 933839...
# Gen #24, Team #37
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -324.0, writes: 934339...
# Gen #24, Team #36
# Finished after 26 steps with cumulative reward 86.0, writes: 934365...
# Gen #24, Team #35
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -397.0, writes: 934865...
# Gen #24, Team #34
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -59.0, writes: 935365...
# Gen #24, Team #33
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -302.0, writes: 935865...
# Gen #24, Team #32
# Finished after 459 steps with cumulative reward -141.0, writes: 936324...
# Gen #24, Team #31
# Finished after 81 steps with cumulative reward 71.0, writes: 936405...
# Gen #24, Team #30
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -396.0, writes: 936904...
# Gen #24, Team #29
# Finished after 213 steps with cumulative reward -85.0, writes: 937117...
# Gen #24, Team #28
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -277.0, writes: 937617...
# Gen #24, Team #27
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -218.0, writes: 938117...
# Gen #24, Team #26
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -252.0, writes: 938617...
# Gen #24, Team #25
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -374.0, writes: 939117...
# Gen #24, Team #24
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -170.0, writes: 939617...
# Gen #24, Team #23
# Finished after 157 steps with cumulative reward 79.0, writes: 939774...
# Gen #24, Team #22
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -244.0, writes: 940274...
# Gen #24, Team #21
# Finished after 122 steps with cumulative reward 64.0, writes: 940396...
# Gen #24, Team #20
# Finished after 270 steps with cumulative reward 32.0, writes: 940666...
# Gen #24, Team #19
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -291.0, writes: 941166...
# Gen #24, Team #18
# Finished after 384 steps with cumulative reward -180.0, writes: 941550...
# Gen #24, Team #17
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -328.0, writes: 941751...
# Gen #24, Team #16
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -246.0, writes: 942251...
# Gen #24, Team #15
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -144.0, writes: 942751...
# Gen #24, Team #14
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -258.0, writes: 943251...
# Gen #24, Team #13
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -328.0, writes: 943751...
# Gen #24, Team #12
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -324.0, writes: 944251...
# Gen #24, Team #11
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -334.0, writes: 944751...
# Gen #24, Team #10
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -225.0, writes: 945251...
# Gen #24, Team #9
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -334.0, writes: 945751...
# Gen #24, Team #8
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -224.0, writes: 946251...
# Gen #24, Team #7
# Finished after 328 steps with cumulative reward 46.0, writes: 946579...
# Gen #24, Team #6
# Finished after 27 steps with cumulative reward 95.0, writes: 946606...
# Gen #24, Team #5
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -47.0, writes: 947106...
# Gen #24, Team #4
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -285.0, writes: 947606...
# Gen #24, Team #3
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -93.0, writes: 948106...
# Gen #24, Team #2
# Finished after 110 steps with cumulative reward 62.0, writes: 948216...
# Gen #24, Team #1
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -367.0, writes: 948716...
# Gen #25, Team #101
# Finished after 487 steps with cumulative reward -173.0, writes: 949203...
# Gen #25, Team #100
# Finished after 74 steps with cumulative reward 42.0, writes: 949277...
# Gen #25, Team #99
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -397.0, writes: 949777...
# Gen #25, Team #98
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -438.0, writes: 950277...
# Gen #25, Team #97
# Finished after 66 steps with cumulative reward 44.0, writes: 950343...
# Gen #25, Team #96
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -450.0, writes: 950843...
# Gen #25, Team #95
# Finished after 38 steps with cumulative reward 72.0, writes: 950881...
# Gen #25, Team #94
# Finished after 455 steps with cumulative reward -279.0, writes: 951336...
# Gen #25, Team #93
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -347.0, writes: 951836...
# Gen #25, Team #92
# Finished after 219 steps with cumulative reward 15.0, writes: 952055...
# Gen #25, Team #91
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -431.0, writes: 952555...
# Gen #25, Team #90
# Finished after 239 steps with cumulative reward -41.0, writes: 952794...
# Gen #25, Team #89
# Finished after 480 steps with cumulative reward -252.0, writes: 953274...
# Gen #25, Team #88
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -357.0, writes: 953774...
# Gen #25, Team #87
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -316.0, writes: 954274...
# Gen #25, Team #86
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -231.0, writes: 954774...
# Gen #25, Team #85
# Finished after 134 steps with cumulative reward 32.0, writes: 954908...
# Gen #25, Team #84
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -349.0, writes: 955408...
# Gen #25, Team #83
# Finished after 115 steps with cumulative reward 43.0, writes: 955523...
# Gen #25, Team #82
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -283.0, writes: 956023...
# Gen #25, Team #81
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -90.0, writes: 956523...
# Gen #25, Team #80
# Finished after 288 steps with cumulative reward -114.0, writes: 956811...
# Gen #25, Team #79
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -394.0, writes: 957311...
# Gen #25, Team #78
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -287.0, writes: 957811...
# Gen #25, Team #77
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -221.0, writes: 958311...
# Gen #25, Team #76
# Finished after 267 steps with cumulative reward -13.0, writes: 958578...
# Gen #25, Team #75
# Finished after 333 steps with cumulative reward -181.0, writes: 958911...
# Gen #25, Team #74
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -168.0, writes: 959411...
# Gen #25, Team #73
# Finished after 263 steps with cumulative reward -83.0, writes: 959674...
# Gen #25, Team #72
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -160.0, writes: 960174...
# Gen #25, Team #71
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -319.0, writes: 960674...
# Gen #25, Team #70
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -322.0, writes: 961174...
# Gen #25, Team #69
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -237.0, writes: 961674...
# Gen #25, Team #68
# Finished after 302 steps with cumulative reward -14.0, writes: 961976...
# Gen #25, Team #67
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -308.0, writes: 962476...
# Gen #25, Team #66
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -336.0, writes: 962976...
# Gen #25, Team #65
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -199.0, writes: 963476...
# Gen #25, Team #64
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -290.0, writes: 963976...
# Gen #25, Team #63
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -238.0, writes: 964476...
# Gen #25, Team #62
# Finished after 62 steps with cumulative reward 88.0, writes: 964538...
# Gen #25, Team #61
# Finished after 58 steps with cumulative reward 56.0, writes: 964596...
# Gen #25, Team #60
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -387.0, writes: 965096...
# Gen #25, Team #59
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -367.0, writes: 965596...
# Gen #25, Team #58
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -342.0, writes: 966096...
# Gen #25, Team #57
# Finished after 31 steps with cumulative reward 83.0, writes: 966127...
# Gen #25, Team #56
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -296.0, writes: 966627...
# Gen #25, Team #55
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -101.0, writes: 967127...
# Gen #25, Team #54
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -223.0, writes: 967627...
# Gen #25, Team #53
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -220.0, writes: 968127...
# Gen #25, Team #52
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -344.0, writes: 968627...
# Gen #25, Team #51
# Finished after 357 steps with cumulative reward -165.0, writes: 968984...
# Gen #25, Team #50
# Finished after 276 steps with cumulative reward -30.0, writes: 969260...
# Gen #25, Team #49
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -442.0, writes: 969760...
# Gen #25, Team #48
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -314.0, writes: 970260...
# Gen #25, Team #47
# Finished after 351 steps with cumulative reward 3.0, writes: 970611...
# Gen #25, Team #46
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -343.0, writes: 971111...
# Gen #25, Team #45
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -260.0, writes: 971611...
# Gen #25, Team #44
# Finished after 400 steps with cumulative reward -68.0, writes: 972011...
# Gen #25, Team #43
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -189.0, writes: 972511...
# Gen #25, Team #42
# Finished after 81 steps with cumulative reward 37.0, writes: 972592...
# Gen #25, Team #41
# Finished after 199 steps with cumulative reward 75.0, writes: 972791...
# Gen #25, Team #40
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -312.0, writes: 973291...
# Gen #25, Team #39
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -256.0, writes: 973791...
# Gen #25, Team #38
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -284.0, writes: 974291...
# Gen #25, Team #37
# Ran out of turns... giving up
# Finished after 500 steps with cumulative reward -228.0, writes: 974791...
# Gen #25, Team #36

# %%
stepInfo = np.array(numStepsStats)
rewardInfo = np.array(rewardStats)

stepInfo.shape, rewardInfo.shape

min_rewards = rewardInfo[:, 0]
max_rewards = rewardInfo[:, 1]
avg_rewards = rewardInfo[:, 2]

min_steps = stepInfo[:, 0]
max_steps = stepInfo[:, 1]
avg_steps = stepInfo[:, 2]

# Create a figure with subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))


# Plot rewards over time
episodes = range(1, len(min_rewards) + 1)
axes[0].plot(episodes, min_rewards, label='Min Rewards', color='#1f78b4', alpha=0.8)
axes[0].plot(episodes, max_rewards, label='Max Rewards', color='#33a02c', alpha=0.8)
axes[0].plot(episodes, avg_rewards, label='Avg Rewards', color='#e31a1c', alpha=0.8)
axes[0].set_title('Rewards over Time')
axes[0].set_xlabel('Generation')
axes[0].set_ylabel('Reward')
axes[0].legend(loc='upper right')
axes[0].grid(True, linestyle='--', alpha=0.6)

# Plot steps over time
axes[1].plot(episodes, min_steps, label='Min Steps', color='#ff7f00', alpha=0.8)
axes[1].plot(episodes, max_steps, label='Max Steps', color='#6a3d9a', alpha=0.8)
axes[1].plot(episodes, avg_steps, label='Avg Steps', color='#fdbf6f', alpha=0.8)
axes[1].set_title('Steps over Time')
axes[1].set_xlabel('Generation')
axes[1].set_ylabel('Steps')
axes[1].legend(loc='upper right')
axes[1].grid(True, linestyle='--', alpha=0.6)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Combine the data into a DataFrame for Seaborn
reward_data = np.concatenate([min_rewards, max_rewards, avg_rewards])
reward_type = np.repeat(['Min', 'Max', 'Avg'], len(min_rewards))
episode_numbers_reward = np.tile(range(1, len(min_rewards) + 1), 3)

steps_data = np.concatenate([min_steps, max_steps, avg_steps])
steps_type = np.repeat(['Min', 'Max', 'Avg'], len(min_steps))
episode_numbers_steps = np.tile(range(1, len(min_steps) + 1), 3)

df_reward = pd.DataFrame({'Episode': episode_numbers_reward, 'Reward': reward_data, 'Type': reward_type})
df_steps = pd.DataFrame({'Episode': episode_numbers_steps, 'Steps': steps_data, 'Type': steps_type})

# Create a figure with subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))

# Create violin plots for rewards
sns.violinplot(x='Type', y='Reward', data=df_reward, color='skyblue', inner='quartile', ax=axes[0])
axes[0].set_title('Distribution of Rewards')
axes[0].set_xlabel('Reward Type')
axes[0].set_ylabel('Reward')
axes[0].grid(True, linestyle='--', alpha=0.6)

# Create violin plots for steps
sns.violinplot(x='Type', y='Steps', data=df_steps, palette="Blues", inner='quartile', ax=axes[1])
axes[1].set_title('Distribution of Steps')
axes[1].set_xlabel('Step Type')
axes[1].set_ylabel('Steps')
axes[1].grid(True, linestyle='--', alpha=0.6)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
